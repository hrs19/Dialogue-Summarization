# %%
import torch
from transformers import Trainer, TrainingArguments
from transformers import BartForConditionalGeneration, BartTokenizer
from transformers import AutoModelForSeq2SeqLM, AutoTokenizer
import os
from datasets import load_dataset,load_metric
# from evaluate import load_metric
from sklearn.model_selection import train_test_split

device = 'cuda:0'
import emoji
emoji_list = emoji.EMOJI_DATA.keys()
emoji_descriptions = [emoji.demojize(e, delimiters=("<", ">")) for e in emoji_list]

# %% [markdown]
# ### Loading the base models from Huggingface

# %%
model_name = "facebook/bart-large-cnn"
model = AutoModelForSeq2SeqLM.from_pretrained(model_name).to(device)
# Out:
# Some weights of BartForConditionalGeneration were not initialized from the model checkpoint at facebook/bart-large-cnn and are newly initialized: ['model.shared.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %% [markdown]
# ### Updating the tokenizer and resizing model embeddings

# %%
tokenizer = AutoTokenizer.from_pretrained(model_name)

new_tokens = ['<file_photo>','<file_picture>','<file_other>','<file_video>','<file_image>','<file_gif>']
new_tokens = new_tokens+emoji_descriptions
tokenizer.add_special_tokens({'additional_special_tokens': new_tokens})
model.resize_token_embeddings(len(tokenizer))

# %% [markdown]
# ### Loading the SAMSum dataset

# %%
dataset = load_dataset("samsum")
train_data = dataset["train"]
validation_data = dataset["validation"] 
test_data = dataset["test"]

# %% [markdown]
# ### Tokenizing Function

# %%
def tokenize_function(tokenizer,examples):
    input_dialogues = ["Summarize dialogue >>\n " + emoji.demojize(dialogue, delimiters=("<", ">")) for dialogue in examples["dialogue"]]
    inputs = tokenizer(input_dialogues, padding="max_length", truncation=True, max_length=1000)
    targets = tokenizer(examples["summary"], padding="max_length", truncation=True, max_length=100)
    return {"input_ids": inputs["input_ids"], "attention_mask": inputs["attention_mask"], "labels": targets["input_ids"]}

# %%
train_data_tokenized = train_data.map(lambda examples: tokenize_function(tokenizer, examples), batched=True)
validation_data_tokenized = validation_data.map(lambda examples: tokenize_function(tokenizer, examples), batched=True)
test_data_tokenized = test_data.map(lambda examples: tokenize_function(tokenizer, examples), batched=True)

# %% [markdown]
# ### Sample summarization code

# %%
def summarize(tokenizer,model,text):
    inputs = tokenizer(f"Summarize dialogue >>\n {emoji.demojize(text, delimiters=('<', '>'))}", return_tensors="pt", max_length=1000, truncation=True, padding="max_length").to(device)    
    summary_ids = model.generate(inputs.input_ids, num_beams=4, max_length=100, early_stopping=True)
    summary = [tokenizer.decode(g, skip_special_tokens=True, clean_up_tokenization_spaces=False) for g in summary_ids]
    
    return summary[0]

text = test_data['dialogue'][0]
summary = summarize(tokenizer,model,text)
print("Generated Summary:"+ summary,'\n\n',train_data['summary'][0])

# %%
# Getting trainabale parameters
trainable_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
print("Trainable parameters:", trainable_params)

# %% [markdown]
# ### Freezing all layers and keeping encoder weights as trainable

# %%
# Freezing model weights/Setting them as trainable based on approach 
for param in model.parameters():
    param.requires_grad = False

for param in model.model.encoder.parameters():
    param.requires_grad = True

for name, param in model.named_parameters():
    print(f"{name} is {'trainable' if param.requires_grad else 'frozen'}")
# Out:
# model.shared.weight is trainable
# model.encoder.embed_positions.weight is trainable
# model.encoder.layers.0.self_attn.k_proj.weight is trainable
# model.encoder.layers.0.self_attn.k_proj.bias is trainable
# model.encoder.layers.0.self_attn.v_proj.weight is trainable
# model.encoder.layers.0.self_attn.v_proj.bias is trainable
# model.encoder.layers.0.self_attn.q_proj.weight is trainable
# model.encoder.layers.0.self_attn.q_proj.bias is trainable
# model.encoder.layers.0.self_attn.out_proj.weight is trainable
# model.encoder.layers.11.self_attn.q_proj.weight is trainable
# model.encoder.layers.11.self_attn.q_proj.bias is trainable
# model.encoder.layers.11.self_attn.out_proj.weight is trainable
# model.encoder.layers.11.self_attn.out_proj.bias is trainable
# model.encoder.layers.11.self_attn_layer_norm.weight is trainable
# model.encoder.layers.11.self_attn_layer_norm.bias is trainable
# model.encoder.layers.11.fc1.weight is trainable
# model.encoder.layers.11.fc1.bias is trainable
# model.encoder.layers.11.fc2.weight is trainable
# model.encoder.layers.11.fc2.bias is trainable
# model.encoder.layers.11.final_layer_norm.weight is trainable
# model.encoder.layers.11.final_layer_norm.bias is trainable
# model.encoder.layernorm_embedding.weight is trainable
# model.encoder.layernorm_embedding.bias is trainable
# model.decoder.embed_positions.weight is frozen
# model.decoder.layers.0.self_attn.k_proj.weight is frozen
# model.decoder.layers.0.self_attn.k_proj.bias is frozen
# model.decoder.layers.0.self_attn.v_proj.weight is frozen
# model.decoder.layers.0.self_attn.v_proj.bias is frozen
# model.decoder.layers.0.self_attn.q_proj.weight is frozen
# model.decoder.layers.0.self_attn.q_proj.bias is frozen
# model.decoder.layers.0.self_attn.out_proj.weight is frozen
# model.decoder.layers.0.self_attn.out_proj.bias is frozen
# model.decoder.layers.0.self_attn_layer_norm.weight is frozen
# model.decoder.layers.0.self_attn_layer_norm.bias is frozen
# model.decoder.layers.0.encoder_attn.k_proj.weight is frozen
# model.decoder.layers.0.encoder_attn.k_proj.bias is frozen
# model.decoder.layers.0.encoder_attn.v_proj.weight is frozen
# model.decoder.layers.0.encoder_attn.v_proj.bias is frozen
# model.decoder.layers.0.encoder_attn.q_proj.weight is frozen
# model.decoder.layers.0.encoder_attn.q_proj.bias is frozen
# model.decoder.layers.0.encoder_attn.out_proj.weight is frozen
# model.decoder.layers.0.encoder_attn.out_proj.bias is frozen
# model.decoder.layers.0.encoder_attn_layer_norm.weight is frozen
# model.decoder.layers.0.encoder_attn_layer_norm.bias is frozen
# model.decoder.layers.0.fc1.weight is frozen
# model.decoder.layers.0.fc1.bias is frozen
# model.decoder.layers.0.fc2.weight is frozen
# model.decoder.layers.0.fc2.bias is frozen
# model.decoder.layers.0.final_layer_norm.weight is frozen
# model.decoder.layers.0.final_layer_norm.bias is frozen
# model.decoder.layers.1.self_attn.k_proj.weight is frozen
# model.decoder.layers.1.self_attn.k_proj.bias is frozen
# model.decoder.layers.1.self_attn.v_proj.weight is frozen
# model.decoder.layers.1.self_attn.v_proj.bias is frozen
# model.decoder.layers.1.self_attn.q_proj.weight is frozen
# model.decoder.layers.1.self_attn.q_proj.bias is frozen
# model.decoder.layers.1.self_attn.out_proj.weight is frozen
# model.decoder.layers.1.self_attn.out_proj.bias is frozen
# model.decoder.layers.1.self_attn_layer_norm.weight is frozen
# model.decoder.layers.1.self_attn_layer_norm.bias is frozen
# model.decoder.layers.1.encoder_attn.k_proj.weight is frozen
# model.decoder.layers.1.encoder_attn.k_proj.bias is frozen
# model.decoder.layers.1.encoder_attn.v_proj.weight is frozen
# model.decoder.layers.1.encoder_attn.v_proj.bias is frozen
# model.decoder.layers.1.encoder_attn.q_proj.weight is frozen
# model.decoder.layers.1.encoder_attn.q_proj.bias is frozen
# model.decoder.layers.1.encoder_attn.out_proj.weight is frozen
# model.decoder.layers.1.encoder_attn.out_proj.bias is frozen
# model.decoder.layers.1.encoder_attn_layer_norm.weight is frozen
# model.decoder.layers.1.encoder_attn_layer_norm.bias is frozen
# model.decoder.layers.1.fc1.weight is frozen
# model.decoder.layers.1.fc1.bias is frozen
# model.decoder.layers.1.fc2.weight is frozen
# model.decoder.layers.1.fc2.bias is frozen
# model.decoder.layers.1.final_layer_norm.weight is frozen
# model.decoder.layers.1.final_layer_norm.bias is frozen
# model.decoder.layers.2.self_attn.k_proj.weight is frozen
# model.decoder.layers.2.self_attn.k_proj.bias is frozen
# model.decoder.layers.2.self_attn.v_proj.weight is frozen
# model.decoder.layers.2.self_attn.v_proj.bias is frozen
# model.decoder.layers.2.self_attn.q_proj.weight is frozen
# model.decoder.layers.2.self_attn.q_proj.bias is frozen
# model.decoder.layers.2.self_attn.out_proj.weight is frozen
# model.decoder.layers.2.self_attn.out_proj.bias is frozen
# model.decoder.layers.2.self_attn_layer_norm.weight is frozen
# model.decoder.layers.2.self_attn_layer_norm.bias is frozen
# model.decoder.layers.2.encoder_attn.k_proj.weight is frozen
# model.decoder.layers.2.encoder_attn.k_proj.bias is frozen
# model.decoder.layers.2.encoder_attn.v_proj.weight is frozen
# model.decoder.layers.2.encoder_attn.v_proj.bias is frozen
# model.decoder.layers.2.encoder_attn.q_proj.weight is frozen
# model.decoder.layers.2.encoder_attn.q_proj.bias is frozen
# model.decoder.layers.2.encoder_attn.out_proj.weight is frozen
# model.decoder.layers.2.encoder_attn.out_proj.bias is frozen
# model.decoder.layers.2.encoder_attn_layer_norm.weight is frozen
# model.decoder.layers.2.encoder_attn_layer_norm.bias is frozen
# model.decoder.layers.2.fc1.weight is frozen
# model.decoder.layers.2.fc1.bias is frozen
# model.decoder.layers.2.fc2.weight is frozen
# model.decoder.layers.2.fc2.bias is frozen
# model.decoder.layers.2.final_layer_norm.weight is frozen
# model.decoder.layers.2.final_layer_norm.bias is frozen
# model.decoder.layers.3.self_attn.k_proj.weight is frozen
# model.decoder.layers.3.self_attn.k_proj.bias is frozen
# model.decoder.layers.3.self_attn.v_proj.weight is frozen
# model.decoder.layers.3.self_attn.v_proj.bias is frozen
# model.decoder.layers.3.self_attn.q_proj.weight is frozen
# model.decoder.layers.3.self_attn.q_proj.bias is frozen
# model.decoder.layers.3.self_attn.out_proj.weight is frozen
# model.decoder.layers.3.self_attn.out_proj.bias is frozen
# model.decoder.layers.3.self_attn_layer_norm.weight is frozen
# model.decoder.layers.3.self_attn_layer_norm.bias is frozen
# model.decoder.layers.3.encoder_attn.k_proj.weight is frozen
# model.decoder.layers.3.encoder_attn.k_proj.bias is frozen
# model.decoder.layers.3.encoder_attn.v_proj.weight is frozen
# model.decoder.layers.3.encoder_attn.v_proj.bias is frozen
# model.decoder.layers.3.encoder_attn.q_proj.weight is frozen
# model.decoder.layers.3.encoder_attn.q_proj.bias is frozen
# model.decoder.layers.3.encoder_attn.out_proj.weight is frozen
# model.decoder.layers.3.encoder_attn.out_proj.bias is frozen
# model.decoder.layers.3.encoder_attn_layer_norm.weight is frozen
# model.decoder.layers.3.encoder_attn_layer_norm.bias is frozen
# model.decoder.layers.3.fc1.weight is frozen
# model.decoder.layers.3.fc1.bias is frozen
# model.decoder.layers.3.fc2.weight is frozen
# model.decoder.layers.3.fc2.bias is frozen
# model.decoder.layers.3.final_layer_norm.weight is frozen
# model.decoder.layers.3.final_layer_norm.bias is frozen
# model.decoder.layers.4.self_attn.k_proj.weight is frozen
# model.decoder.layers.4.self_attn.k_proj.bias is frozen
# model.decoder.layers.4.self_attn.v_proj.weight is frozen
# model.decoder.layers.4.self_attn.v_proj.bias is frozen
# model.decoder.layers.4.self_attn.q_proj.weight is frozen
# model.decoder.layers.4.self_attn.q_proj.bias is frozen
# model.decoder.layers.4.self_attn.out_proj.weight is frozen
# model.decoder.layers.4.self_attn.out_proj.bias is frozen
# model.decoder.layers.4.self_attn_layer_norm.weight is frozen
# model.decoder.layers.4.self_attn_layer_norm.bias is frozen
# model.decoder.layers.4.encoder_attn.k_proj.weight is frozen
# model.decoder.layers.4.encoder_attn.k_proj.bias is frozen
# model.decoder.layers.4.encoder_attn.v_proj.weight is frozen
# model.decoder.layers.4.encoder_attn.v_proj.bias is frozen
# model.decoder.layers.4.encoder_attn.q_proj.weight is frozen
# model.decoder.layers.4.encoder_attn.q_proj.bias is frozen
# model.decoder.layers.4.encoder_attn.out_proj.weight is frozen
# model.decoder.layers.4.encoder_attn.out_proj.bias is frozen
# model.decoder.layers.4.encoder_attn_layer_norm.weight is frozen
# model.decoder.layers.4.encoder_attn_layer_norm.bias is frozen
# model.decoder.layers.4.fc1.weight is frozen
# model.decoder.layers.4.fc1.bias is frozen
# model.decoder.layers.4.fc2.weight is frozen
# model.decoder.layers.4.fc2.bias is frozen
# model.decoder.layers.4.final_layer_norm.weight is frozen
# model.decoder.layers.4.final_layer_norm.bias is frozen
# model.decoder.layers.5.self_attn.k_proj.weight is frozen
# model.decoder.layers.5.self_attn.k_proj.bias is frozen
# model.decoder.layers.5.self_attn.v_proj.weight is frozen
# model.decoder.layers.5.self_attn.v_proj.bias is frozen
# model.decoder.layers.5.self_attn.q_proj.weight is frozen
# model.decoder.layers.5.self_attn.q_proj.bias is frozen
# model.decoder.layers.5.self_attn.out_proj.weight is frozen
# model.decoder.layers.5.self_attn.out_proj.bias is frozen
# model.decoder.layers.5.self_attn_layer_norm.weight is frozen
# model.decoder.layers.5.self_attn_layer_norm.bias is frozen
# model.decoder.layers.5.encoder_attn.k_proj.weight is frozen
# model.decoder.layers.5.encoder_attn.k_proj.bias is frozen
# model.decoder.layers.5.encoder_attn.v_proj.weight is frozen
# model.decoder.layers.5.encoder_attn.v_proj.bias is frozen
# model.decoder.layers.5.encoder_attn.q_proj.weight is frozen
# model.decoder.layers.5.encoder_attn.q_proj.bias is frozen
# model.decoder.layers.5.encoder_attn.out_proj.weight is frozen
# model.decoder.layers.5.encoder_attn.out_proj.bias is frozen
# model.decoder.layers.5.encoder_attn_layer_norm.weight is frozen
# model.decoder.layers.5.encoder_attn_layer_norm.bias is frozen
# model.decoder.layers.5.fc1.weight is frozen
# model.decoder.layers.5.fc1.bias is frozen
# model.decoder.layers.5.fc2.weight is frozen
# model.decoder.layers.5.fc2.bias is frozen
# model.decoder.layers.5.final_layer_norm.weight is frozen
# model.decoder.layers.5.final_layer_norm.bias is frozen
# model.decoder.layers.6.self_attn.k_proj.weight is frozen
# model.decoder.layers.6.self_attn.k_proj.bias is frozen
# model.decoder.layers.6.self_attn.v_proj.weight is frozen
# model.decoder.layers.6.self_attn.v_proj.bias is frozen
# model.decoder.layers.6.self_attn.q_proj.weight is frozen
# model.decoder.layers.6.self_attn.q_proj.bias is frozen
# model.decoder.layers.6.self_attn.out_proj.weight is frozen
# model.decoder.layers.6.self_attn.out_proj.bias is frozen
# model.decoder.layers.6.self_attn_layer_norm.weight is frozen
# model.decoder.layers.6.self_attn_layer_norm.bias is frozen
# model.decoder.layers.6.encoder_attn.k_proj.weight is frozen
# model.decoder.layers.6.encoder_attn.k_proj.bias is frozen
# model.decoder.layers.6.encoder_attn.v_proj.weight is frozen
# model.decoder.layers.6.encoder_attn.v_proj.bias is frozen
# model.decoder.layers.6.encoder_attn.q_proj.weight is frozen
# model.decoder.layers.6.encoder_attn.q_proj.bias is frozen
# model.decoder.layers.6.encoder_attn.out_proj.weight is frozen
# model.decoder.layers.6.encoder_attn.out_proj.bias is frozen
# model.decoder.layers.6.encoder_attn_layer_norm.weight is frozen
# model.decoder.layers.6.encoder_attn_layer_norm.bias is frozen
# model.decoder.layers.6.fc1.weight is frozen
# model.decoder.layers.6.fc1.bias is frozen
# model.decoder.layers.6.fc2.weight is frozen
# model.decoder.layers.6.fc2.bias is frozen
# model.decoder.layers.6.final_layer_norm.weight is frozen
# model.decoder.layers.6.final_layer_norm.bias is frozen
# model.decoder.layers.7.self_attn.k_proj.weight is frozen
# model.decoder.layers.7.self_attn.k_proj.bias is frozen
# model.decoder.layers.7.self_attn.v_proj.weight is frozen
# model.decoder.layers.7.self_attn.v_proj.bias is frozen
# model.decoder.layers.7.self_attn.q_proj.weight is frozen
# model.decoder.layers.7.self_attn.q_proj.bias is frozen
# model.decoder.layers.7.self_attn.out_proj.weight is frozen
# model.decoder.layers.7.self_attn.out_proj.bias is frozen
# model.decoder.layers.7.self_attn_layer_norm.weight is frozen
# model.decoder.layers.7.self_attn_layer_norm.bias is frozen
# model.decoder.layers.7.encoder_attn.k_proj.weight is frozen
# model.decoder.layers.7.encoder_attn.k_proj.bias is frozen
# model.decoder.layers.7.encoder_attn.v_proj.weight is frozen
# model.decoder.layers.7.encoder_attn.v_proj.bias is frozen
# model.decoder.layers.7.encoder_attn.q_proj.weight is frozen
# model.decoder.layers.7.encoder_attn.q_proj.bias is frozen
# model.decoder.layers.7.encoder_attn.out_proj.weight is frozen
# model.decoder.layers.7.encoder_attn.out_proj.bias is frozen
# model.decoder.layers.7.encoder_attn_layer_norm.weight is frozen
# model.decoder.layers.7.encoder_attn_layer_norm.bias is frozen
# model.decoder.layers.7.fc1.weight is frozen
# model.decoder.layers.7.fc1.bias is frozen
# model.decoder.layers.7.fc2.weight is frozen
# model.decoder.layers.7.fc2.bias is frozen
# model.decoder.layers.7.final_layer_norm.weight is frozen
# model.decoder.layers.7.final_layer_norm.bias is frozen
# model.decoder.layers.8.self_attn.k_proj.weight is frozen
# model.decoder.layers.8.self_attn.k_proj.bias is frozen
# model.decoder.layers.8.self_attn.v_proj.weight is frozen
# model.decoder.layers.8.self_attn.v_proj.bias is frozen
# model.decoder.layers.8.self_attn.q_proj.weight is frozen
# model.decoder.layers.8.self_attn.q_proj.bias is frozen
# model.decoder.layers.8.self_attn.out_proj.weight is frozen
# model.decoder.layers.8.self_attn.out_proj.bias is frozen
# model.decoder.layers.8.self_attn_layer_norm.weight is frozen
# model.decoder.layers.8.self_attn_layer_norm.bias is frozen
# model.decoder.layers.8.encoder_attn.k_proj.weight is frozen
# model.decoder.layers.8.encoder_attn.k_proj.bias is frozen
# model.decoder.layers.8.encoder_attn.v_proj.weight is frozen
# model.decoder.layers.8.encoder_attn.v_proj.bias is frozen
# model.decoder.layers.8.encoder_attn.q_proj.weight is frozen
# model.decoder.layers.8.encoder_attn.q_proj.bias is frozen
# model.decoder.layers.8.encoder_attn.out_proj.weight is frozen
# model.decoder.layers.8.encoder_attn.out_proj.bias is frozen
# model.decoder.layers.8.encoder_attn_layer_norm.weight is frozen
# model.decoder.layers.8.encoder_attn_layer_norm.bias is frozen
# model.decoder.layers.8.fc1.weight is frozen
# model.decoder.layers.8.fc1.bias is frozen
# model.decoder.layers.8.fc2.weight is frozen
# model.decoder.layers.8.fc2.bias is frozen
# model.decoder.layers.8.final_layer_norm.weight is frozen
# model.decoder.layers.8.final_layer_norm.bias is frozen
# model.decoder.layers.9.self_attn.k_proj.weight is frozen
# model.decoder.layers.9.self_attn.k_proj.bias is frozen
# model.decoder.layers.9.self_attn.v_proj.weight is frozen
# model.decoder.layers.9.self_attn.v_proj.bias is frozen
# model.decoder.layers.9.self_attn.q_proj.weight is frozen
# model.decoder.layers.9.self_attn.q_proj.bias is frozen
# model.decoder.layers.9.self_attn.out_proj.weight is frozen
# model.decoder.layers.9.self_attn.out_proj.bias is frozen
# model.decoder.layers.9.self_attn_layer_norm.weight is frozen
# model.decoder.layers.9.self_attn_layer_norm.bias is frozen
# model.decoder.layers.9.encoder_attn.k_proj.weight is frozen
# model.decoder.layers.9.encoder_attn.k_proj.bias is frozen
# model.decoder.layers.9.encoder_attn.v_proj.weight is frozen
# model.decoder.layers.9.encoder_attn.v_proj.bias is frozen
# model.decoder.layers.9.encoder_attn.q_proj.weight is frozen
# model.decoder.layers.9.encoder_attn.q_proj.bias is frozen
# model.decoder.layers.9.encoder_attn.out_proj.weight is frozen
# model.decoder.layers.9.encoder_attn.out_proj.bias is frozen
# model.decoder.layers.9.encoder_attn_layer_norm.weight is frozen
# model.decoder.layers.9.encoder_attn_layer_norm.bias is frozen
# model.decoder.layers.9.fc1.weight is frozen
# model.decoder.layers.9.fc1.bias is frozen
# model.decoder.layers.9.fc2.weight is frozen
# model.decoder.layers.9.fc2.bias is frozen
# model.decoder.layers.9.final_layer_norm.weight is frozen
# model.decoder.layers.9.final_layer_norm.bias is frozen
# model.decoder.layers.10.self_attn.k_proj.weight is frozen
# model.decoder.layers.10.self_attn.k_proj.bias is frozen
# model.decoder.layers.10.self_attn.v_proj.weight is frozen
# model.decoder.layers.10.self_attn.v_proj.bias is frozen
# model.decoder.layers.10.self_attn.q_proj.weight is frozen
# model.decoder.layers.10.self_attn.q_proj.bias is frozen
# model.decoder.layers.10.self_attn.out_proj.weight is frozen
# model.decoder.layers.10.self_attn.out_proj.bias is frozen
# model.decoder.layers.10.self_attn_layer_norm.weight is frozen
# model.decoder.layers.10.self_attn_layer_norm.bias is frozen
# model.decoder.layers.10.encoder_attn.k_proj.weight is frozen
# model.decoder.layers.10.encoder_attn.k_proj.bias is frozen
# model.decoder.layers.10.encoder_attn.v_proj.weight is frozen
# model.decoder.layers.10.encoder_attn.v_proj.bias is frozen
# model.decoder.layers.10.encoder_attn.q_proj.weight is frozen
# model.decoder.layers.10.encoder_attn.q_proj.bias is frozen
# model.decoder.layers.10.encoder_attn.out_proj.weight is frozen
# model.decoder.layers.10.encoder_attn.out_proj.bias is frozen
# model.decoder.layers.10.encoder_attn_layer_norm.weight is frozen
# model.decoder.layers.10.encoder_attn_layer_norm.bias is frozen
# model.decoder.layers.10.fc1.weight is frozen
# model.decoder.layers.10.fc1.bias is frozen
# model.decoder.layers.10.fc2.weight is frozen
# model.decoder.layers.10.fc2.bias is frozen
# model.decoder.layers.10.final_layer_norm.weight is frozen
# model.decoder.layers.10.final_layer_norm.bias is frozen
# model.decoder.layers.11.self_attn.k_proj.weight is frozen
# model.decoder.layers.11.self_attn.k_proj.bias is frozen
# model.decoder.layers.11.self_attn.v_proj.weight is frozen
# model.decoder.layers.11.self_attn.v_proj.bias is frozen
# model.decoder.layers.11.self_attn.q_proj.weight is frozen
# model.decoder.layers.11.self_attn.q_proj.bias is frozen
# model.decoder.layers.11.self_attn.out_proj.weight is frozen
# model.decoder.layers.11.self_attn.out_proj.bias is frozen
# model.decoder.layers.11.self_attn_layer_norm.weight is frozen
# model.decoder.layers.11.self_attn_layer_norm.bias is frozen
# model.decoder.layers.11.encoder_attn.k_proj.weight is frozen
# model.decoder.layers.11.encoder_attn.k_proj.bias is frozen
# model.decoder.layers.11.encoder_attn.v_proj.weight is frozen
# model.decoder.layers.11.encoder_attn.v_proj.bias is frozen
# model.decoder.layers.11.encoder_attn.q_proj.weight is frozen
# model.decoder.layers.11.encoder_attn.q_proj.bias is frozen
# model.decoder.layers.11.encoder_attn.out_proj.weight is frozen
# model.decoder.layers.11.encoder_attn.out_proj.bias is frozen
# model.decoder.layers.11.encoder_attn_layer_norm.weight is frozen
# model.decoder.layers.11.encoder_attn_layer_norm.bias is frozen
# model.decoder.layers.11.fc1.weight is frozen
# model.decoder.layers.11.fc1.bias is frozen
# model.decoder.layers.11.fc2.weight is frozen
# model.decoder.layers.11.fc2.bias is frozen
# model.decoder.layers.11.final_layer_norm.weight is frozen
# model.decoder.layers.11.final_layer_norm.bias is frozen
# model.decoder.layernorm_embedding.weight is frozen
# model.decoder.layernorm_embedding.bias is frozen

# %%
trainable_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
print("Trainable parameters:", trainable_params)
# Out:
# Trainable parameters: 203677696

# %% [markdown]
# ### Training

# %%
output_dir = "./bart_large_encoder_finetune_emoji"

# %%
training_args = TrainingArguments(
#     eval_device='cpu',
    overwrite_output_dir = False,
    output_dir=output_dir,
    per_device_train_batch_size=4,
    per_device_eval_batch_size=4,
#     evaluation_strategy="steps",
    logging_dir=f"{output_dir}/logs",
    logging_steps=500,
    save_strategy="epoch",
    save_total_limit=3,
    num_train_epochs=10,
    learning_rate=1e-4,
)

rouge_metric = load_metric("rouge")

trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=train_data_tokenized,
    eval_dataset=validation_data_tokenized,
    compute_metrics=lambda pred: rouge_metric.compute(predictions=pred.predictions, references=pred.label_ids)
)
# Out:
# <ipython-input-12-5ff3adaaf92c>:16: FutureWarning: load_metric is deprecated and will be removed in the next major version of datasets. Use 'evaluate.load' instead, from the new library 🤗 Evaluate: https://huggingface.co/docs/evaluate
#   rouge_metric = load_metric("rouge")
# /home/sampgaon.h/.local/lib/python3.8/site-packages/datasets/load.py:756: FutureWarning: The repository for rouge contains custom code which must be executed to correctly load the metric. You can inspect the repository content at https://raw.githubusercontent.com/huggingface/datasets/2.18.0/metrics/rouge/rouge.py
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this metric from the next major release of `datasets`.
#   warnings.warn(

# %%
trainer.train(resume_from_checkpoint = True)
# Out:
# /home/sampgaon.h/.local/lib/python3.8/site-packages/transformers/optimization.py:391: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
#     <div>
#
#       <progress value='36830' max='36830' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [36830/36830 2:05:13, Epoch 10/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>29500</td>
#       <td>0.053100</td>
#     </tr>
#     <tr>
#       <td>30000</td>
#       <td>0.056200</td>
#     </tr>
#     <tr>
#       <td>30500</td>
#       <td>0.056400</td>
#     </tr>
#     <tr>
#       <td>31000</td>
#       <td>0.055800</td>
#     </tr>
#     <tr>
#       <td>31500</td>
#       <td>0.055400</td>
#     </tr>
#     <tr>
#       <td>32000</td>
#       <td>0.055400</td>
#     </tr>
#     <tr>
#       <td>32500</td>
#       <td>0.056900</td>
#     </tr>
#     <tr>
#       <td>33000</td>
#       <td>0.054300</td>
#     </tr>
#     <tr>
#       <td>33500</td>
#       <td>0.045200</td>
#     </tr>
#     <tr>
#       <td>34000</td>
#       <td>0.038300</td>
#     </tr>
#     <tr>
#       <td>34500</td>
#       <td>0.038400</td>
#     </tr>
#     <tr>
#       <td>35000</td>
#       <td>0.039800</td>
#     </tr>
#     <tr>
#       <td>35500</td>
#       <td>0.040000</td>
#     </tr>
#     <tr>
#       <td>36000</td>
#       <td>0.040200</td>
#     </tr>
#     <tr>
#       <td>36500</td>
#       <td>0.040600</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=36830, training_loss=0.00954918435433621, metrics={'train_runtime': 7515.1438, 'train_samples_per_second': 19.603, 'train_steps_per_second': 4.901, 'total_flos': 3.11961479675904e+17, 'train_loss': 0.00954918435433621, 'epoch': 10.0})

# %%
# trainer.save_model('./bart_large_encoder_decoder2_finetune_emoji_save_10')
# tokenizer.save_pretrained('./tokenizer-emoji_large')

model_tok_save_directory = "./bart_large_encoder_finetune_model_tokenizer"
model.save_pretrained(model_tok_save_directory)
tokenizer.save_pretrained(model_tok_save_directory)


eval_trainer = Trainer(
    model=model,
    eval_dataset=validation_data_tokenized,
    compute_metrics=lambda pred: rouge_metric.compute(predictions=pred.predictions, references=pred.label_ids)
)

results = eval_trainer.evaluate(test_data)
print("ROUGE scores:", results)
# Out:
# ROUGE scores: {'eval_runtime': 0.0017, 'eval_samples_per_second': 0.0, 'eval_steps_per_second': 0.0}

# %%
model_tok_save_directory = "./bart_large_encoder_finetune_model_tokenizer"
# Out:
# The history saving thread hit an unexpected error (OperationalError('unable to open database file')).History will not be written to the database.

# %%
model_name = "facebook/bart-base"
orignal_model = AutoModelForSeq2SeqLM.from_pretrained(model_name).to(device)
orignal_model_tok = AutoTokenizer.from_pretrained(model_name)

# %% [markdown]
# ### ROUGE SCORE

# %%
def summarize(tokenizer,model,text):
    """
    Summarizes the given text using the provided tokenizer and model.

    Args:
        tokenizer (Tokenizer): The tokenizer used to tokenize the input text.
        model (Model): The model used for summarization.
        text (str): The text to be summarized.

    Returns:
        list: A list containing the summarized text.    
    """
#     print(f"Summarize dialogue >>\n {emoji.demojize(text, delimiters=('<', '>'))}")
    inputs = tokenizer(f"Summarize dialogue >>\n {emoji.demojize(text, delimiters=('<', '>'))}", return_tensors="pt", max_length=1000, truncation=True, padding="max_length").to(device)
    
    # Generate summary output with max 100 token limit from the model using beam search with 4 beams
    summary_ids = model.generate(inputs.input_ids, num_beams=4, max_length=100, early_stopping=True)
    
    # Decode the generated token ids to human-readable text
    summary = [tokenizer.decode(g, skip_special_tokens=True, clean_up_tokenization_spaces=False) for g in summary_ids]
    
    return summary

# Initializing lists to collect summaries
generated_summaries = []
actual_summaries = []
generated_summary_orignal = []
dialogue_list = []

# Loading saved model
SAVED_MODEL_PATH = './bart_large_encoder_finetune_model_tokenizer'
SAVED_TOK_PATH = 'tokenizer-emoji'
SAVED_MODEL_TOK = BartTokenizer.from_pretrained(SAVED_MODEL_PATH)#.to(device)
SAVED_MODEL = BartForConditionalGeneration.from_pretrained(SAVED_MODEL_PATH).to(device)

# Loading base model
model_name = "facebook/bart-large-cnn"
orignal_model = AutoModelForSeq2SeqLM.from_pretrained(model_name).to(device)
orignal_model_tok = AutoTokenizer.from_pretrained(model_name)
# Out:
# Some weights of BartForConditionalGeneration were not initialized from the model checkpoint at facebook/bart-large-cnn and are newly initialized: ['model.shared.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %% [markdown]
# ### Inference loop to generate summaries on test dataset for ROUGE metrics

# %%
import time
start_time = time.time()
i=1
j=0
for example in test_data:
    if i%10==0:
        j+=10
        print(f"samples summarized:{j}\ttime:{time.time()-start_time}")
    generated_summary = summarize(SAVED_MODEL_TOK,SAVED_MODEL,example['dialogue'])
    generated_summaries.append(generated_summary[0])
    generated_summary_o = summarize(orignal_model_tok,orignal_model,example['dialogue'])
    generated_summary_orignal.append(generated_summary_o[0])
    actual_summaries.append(example["summary"])
    dialogue_list.append(example['dialogue'])
    
    i+=1
    
end_time = time.time()
total_time = end_time - start_time
print(f"Total time taken: {total_time} seconds")
# Out:
# samples summarized:10	time:20.571375131607056
# samples summarized:20	time:44.63774013519287
# samples summarized:30	time:68.42378640174866
# samples summarized:40	time:93.21911549568176
# samples summarized:50	time:117.08969044685364
# samples summarized:60	time:140.388281583786
# samples summarized:70	time:163.61993598937988
# samples summarized:80	time:187.44166350364685
# samples summarized:90	time:210.59677004814148
# samples summarized:100	time:233.6715476512909
# samples summarized:110	time:256.4484496116638
# samples summarized:120	time:279.9146966934204
# samples summarized:130	time:303.4612007141113
# samples summarized:140	time:326.7504403591156
# samples summarized:150	time:349.6736373901367
# samples summarized:160	time:373.33531188964844
# samples summarized:170	time:396.267516374588
# samples summarized:180	time:420.04986119270325
# samples summarized:190	time:443.95052194595337
# samples summarized:200	time:467.72225856781006
# samples summarized:210	time:490.8303346633911
# samples summarized:220	time:514.2575378417969
# samples summarized:230	time:538.1258480548859
# samples summarized:240	time:561.5625193119049
# samples summarized:250	time:584.3729448318481
# samples summarized:260	time:607.5541338920593
# samples summarized:270	time:630.8884484767914
# samples summarized:280	time:654.5819158554077
# samples summarized:290	time:677.8629970550537
# samples summarized:300	time:701.4926736354828
# samples summarized:310	time:725.2720601558685
# samples summarized:320	time:748.3072371482849
# samples summarized:330	time:771.8708627223969
# samples summarized:340	time:796.016982793808
# samples summarized:350	time:820.736857175827
# samples summarized:360	time:844.9427409172058
# samples summarized:370	time:868.5100975036621
# samples summarized:380	time:891.4905393123627
# samples summarized:390	time:914.8624625205994
# samples summarized:400	time:939.5462145805359
# samples summarized:410	time:964.2504987716675
# samples summarized:420	time:988.2350370883942
# samples summarized:430	time:1011.9765424728394
# samples summarized:440	time:1035.3312849998474
# samples summarized:450	time:1059.3039362430573
# samples summarized:460	time:1083.122637271881
# samples summarized:470	time:1106.4317600727081
# samples summarized:480	time:1129.9051644802094
# samples summarized:490	time:1154.3478355407715
# samples summarized:500	time:1178.4054384231567
# samples summarized:510	time:1203.1161255836487
# samples summarized:520	time:1226.2705776691437
# samples summarized:530	time:1250.0569491386414
# samples summarized:540	time:1274.9631085395813
# samples summarized:550	time:1298.6476538181305
# samples summarized:560	time:1322.474829673767
# samples summarized:570	time:1346.3957583904266
# samples summarized:580	time:1370.0845561027527
# samples summarized:590	time:1394.5959677696228
# samples summarized:600	time:1418.3312985897064
# samples summarized:610	time:1441.7308690547943
# samples summarized:620	time:1465.3059051036835
# samples summarized:630	time:1489.2582986354828
# samples summarized:640	time:1512.7428393363953
# samples summarized:650	time:1536.7651283740997
# samples summarized:660	time:1561.4520611763
# samples summarized:670	time:1585.0179340839386
# samples summarized:680	time:1609.1332828998566
# samples summarized:690	time:1633.6293725967407
# samples summarized:700	time:1658.8841581344604
# samples summarized:710	time:1682.5873880386353
# samples summarized:720	time:1705.7913064956665
# samples summarized:730	time:1728.7339849472046
# samples summarized:740	time:1752.3518314361572
# samples summarized:750	time:1776.3081090450287
# samples summarized:760	time:1799.7588715553284
# samples summarized:770	time:1823.7052404880524
# samples summarized:780	time:1846.8563740253448
# samples summarized:790	time:1870.9969532489777
# samples summarized:800	time:1894.4319958686829
# samples summarized:810	time:1918.6013042926788
# Total time taken: 1941.9443578720093 seconds

# %% [markdown]
# ### ROUGE for orignal base model

# %%
from rouge_score import rouge_scorer

start_time = time.time()

scorer = rouge_scorer.RougeScorer(['rouge1', 'rouge2', 'rougeL'], use_stemmer=True)
scores = [scorer.score(actual_summary, gen_summary) for actual_summary, gen_summary in zip(actual_summaries, generated_summary_orignal)]
end_time = time.time()
total_time = end_time - start_time
print(f"Total time taken: {total_time} seconds")

start_time = time.time()

# To calculate average scores
average_scores = {}
for key in scores[0].keys():
    average_scores[key] = sum(score[key].fmeasure for score in scores) / len(scores)

    
end_time = time.time()
total_time = end_time - start_time
print(f"Total time taken: {total_time} seconds")    
print("Average ROUGE scores:")
for key, value in average_scores.items():
    print(f"{key}: {value}")
# Out:
# Total time taken: 1.124314308166504 seconds
# Total time taken: 0.0004980564117431641 seconds
# Average ROUGE scores:
# rouge1: 0.30412814809078337
# rouge2: 0.10309376001724774
# rougeL: 0.22742836389781787

# %% [markdown]
# ### ROUGE for fine-tuned model

# %%
from rouge_score import rouge_scorer

start_time = time.time()

scorer = rouge_scorer.RougeScorer(['rouge1', 'rouge2', 'rougeL'], use_stemmer=True)
scores = [scorer.score(actual_summary, gen_summary) for actual_summary, gen_summary in zip(actual_summaries, generated_summaries)]
end_time = time.time()
total_time = end_time - start_time
print(f"Total time taken: {total_time} seconds")

start_time = time.time()

# To calculate average scores
average_scores = {}
for key in scores[0].keys():
    average_scores[key] = sum(score[key].fmeasure for score in scores) / len(scores)

    
end_time = time.time()
total_time = end_time - start_time
print(f"Total time taken: {total_time} seconds")    
print("Average ROUGE scores:")
for key, value in average_scores.items():
    print(f"{key}: {value}")
# Out:
# Total time taken: 1.0781407356262207 seconds
# Total time taken: 0.0004909038543701172 seconds
# Average ROUGE scores:
# rouge1: 0.38902052351633026
# rouge2: 0.18001246106848157
# rougeL: 0.2922479755135327

# %% [markdown]
# ### Saving the generated summarries

# %%
import pandas as pd


temp_df = pd.DataFrame({'finetune_summary':generated_summaries,'original_summary':generated_summary_orignal,'human_summary':actual_summaries})

# %%
temp_df.to_csv('results.csv')#.loc[3][0]
